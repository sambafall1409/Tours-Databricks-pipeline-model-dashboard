# %%
# 🔁 Lire les données du layer Bronze (fichier CSV)
df = spark.read \
    .option("header", True) \
    .option("inferSchema", True) \
    .option("multiline", True) \
    .option("quote", '"') \
    .option("escape", '"') \
    .csv("/mnt/dvfbronze/mutation.csv")

# %%
#je lestcoke sous format deltatable lmode overwrite ecrase l'ancien fichier par contre 
df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("dvfbronze.mutation")

# %%
# %sql
--verifions si nos données sont bien stockées
SELECT * FROM dvfbronze.mutation LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
